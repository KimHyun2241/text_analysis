# %%
import os
import sys
import requests
import re
import time
import json
import pandas as pd
import csv
from datetime import datetime
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

import warnings
warnings.filterwarnings('ignore')

# %%
extracts = re.compile('[^ 가-힣|a-z|A-Z|0-9|\[|\]|(|)|-|~|?|!|.|:|;|%]+')

nowDatetime = datetime.now().strftime('%Y-%m-%d') # 날짜 표기를 위함

# %%
# 서울 강남
# data_url = open('./data/goodchoice_seoul_Gangnam[' + nowDatetime +'].csv', 'w', encoding='utf8') # url 저장 관련 csv파일
# data = open('./data/info_seoul_Gangnam[' + nowDatetime +'].csv', 'w', encoding='utf8') # 정보 저장관련 csv 파일
# data_r = open('./reviews/reviews_seoul_Gangnam[' + nowDatetime +'].csv', 'w', encoding='utf8') # 리뷰 저장관련 csv 파일

# 서울 용산, 중구, 명동, 이태원
# data_url = open('./data/goodchoice_seoul_Itaewon[' + nowDatetime +'].csv', 'w', encoding='utf8') # url 저장 관련 csv파일
# data = open('./data/info_seoul_Itaewon[' + nowDatetime +'].csv', 'w', encoding='utf8') # 정보 저장관련 csv 파일
# data_r = open('./reviews/reviews_seoul_Itaewon[' + nowDatetime +'].csv', 'w', encoding='utf8') # 리뷰 저장관련 csv 파일

# 서울 건대, 광진, 구의
# data_url = open('./data/goodchoice_seoul_Gundae[' + nowDatetime +'].csv', 'w', encoding='utf8') # url 저장 관련 csv파일
# data = open('./data/info_seoul_Gundae[' + nowDatetime +'].csv', 'w', encoding='utf8') # 정보 저장관련 csv 파일
# data_r = open('./reviews/reviews_seoul_Gundae[' + nowDatetime +'].csv', 'w', encoding='utf8') # 리뷰 저장관련 csv 파일

# 부산 광안리
# data_url = open('./data/goodchoice_busan_Gwanganlli[' + nowDatetime +'].csv', 'w', encoding='utf8') # url 저장 관련 csv파일
# data = open('./data/info_busan_Gwanganlli[' + nowDatetime +'].csv', 'w', encoding='utf8') # 정보 저장관련 csv 파일
# data_r = open('./reviews/reviews_busan_Gwanganlli[' + nowDatetime +'].csv', 'w', encoding='utf8') # 리뷰 저장관련 csv 파일

# 부산 해운대
# data_url = open('./data/goodchoice_busan_Haeundae[' + nowDatetime +'].csv', 'w', encoding='utf8') # url 저장 관련 csv파일
# data = open('./data/info_busan_Haeundae[' + nowDatetime +'].csv', 'w', encoding='utf8') # 정보 저장관련 csv 파일
# data_r = open('./reviews/reviews_busan_Haeundae[' + nowDatetime +'].csv', 'w', encoding='utf8') # 리뷰 저장관련 csv 파일

# 부산 부산역
# data_url = open('./data/goodchoice_busan_station[' + nowDatetime +'].csv', 'w', encoding='utf8') # url 저장 관련 csv파일
# data = open('./data/info_busan_station[' + nowDatetime +'].csv', 'w', encoding='utf8') # 정보 저장관련 csv 파일
# data_r = open('./reviews/reviews_busan_station[' + nowDatetime +'].csv', 'w', encoding='utf8') # 리뷰 저장관련 csv 파일

# 부산 서면
data_url = open('./data/goodchoice_busan_seomyun[' + nowDatetime +'].csv', 'w', encoding='utf8') # url 저장 관련 csv파일
data = open('./data/info_busan_seomyun[' + nowDatetime +'].csv', 'w', encoding='utf8') # 정보 저장관련 csv 파일
data_r = open('./reviews/reviews_busan_seomyun[' + nowDatetime +'].csv', 'w', encoding='utf8') # 리뷰 저장관련 csv 파일

# %%
driver = webdriver.Chrome("chromedriver.exe")
# driver.maximize_window() #전체 화면
# Url = 'https://www.goodchoice.kr/product/search/1/7052'  # 서울 역삼, 강남, 논현
# Url = 'https://www.goodchoice.kr/product/search/1/120'   # 서울 용산, 중구, 명동, 이태원
# Url = 'https://www.goodchoice.kr/product/search/1/135'   # 건대, 광진, 구의
# Url = 'https://www.goodchoice.kr/product/search/1/7044'  # 부산 광안리, 수영, 민락
# Url = 'https://www.goodchoice.kr/product/search/1/101'   # 부산 해운대, 재송
# Url = 'https://www.goodchoice.kr/product/search/1/261'   # 부산 부산역
Url = 'https://www.goodchoice.kr/product/search/1/103'   # 부산 서면
driver.get(Url)

# %%
urls = driver.find_element(By.ID, "poduct_list_area")
urlList = urls.find_elements(By.TAG_NAME, 'li')

for li in urlList:
    aTag = li.find_element(By.TAG_NAME, 'a')
    href = aTag.get_attribute('href')
    data_url.write(href)
    data_url.write('\n')

data_url.close()

# %%
data.write('"name"')
data.write('|')
data.write('"reviews"')
data.write('|')
data.write('"star"')
data.write('\n')

# %%
# 서울 강남
# f = open('D:/webcc/data/goodchoice_seoul_Gangnam[' + nowDatetime +'].csv', 'r', encoding='utf8') #622 컴퓨터
# f = open('C:/python/빅데이터시스템/team/data/goodchoice_seoul_Gangnam[' + nowDatetime +'].csv', 'r', encoding='utf8') # 노트북

# 서울 용산, 중구, 명동, 이태원
# f = open('D:/webcc/data/goodchoice_seoul_Itaewon[' + nowDatetime +'].csv', 'r', encoding='utf8') #622 컴퓨터
# f = open('C:/python/빅데이터시스템/team/data/goodchoice_seoul_Itaewon[' + nowDatetime +'].csv', 'r', encoding='utf8') # 노트북

# 서울 건대, 광진, 구의
# f = open('D:/webcc/data/goodchoice_seoul_Itaewon[' + nowDatetime +'].csv', 'r', encoding='utf8') #622 컴퓨터
# f = open('C:/python/빅데이터시스템/team/data/goodchoice_seoul_Gundae[' + nowDatetime +'].csv', 'r', encoding='utf8') # 노트북

# 부산 광안리
# f = open('./data/info_busan_Gwanganlli[' + nowDatetime +'].csv', 'r', encoding='utf8') #노트북
# f = open('D:/webcc/data/goodchoice_Gwangalli[' + nowDatetime +'].csv', 'r', encoding='utf8') #622 컴퓨터

# 부산 광안리
# f = open('C:/python/빅데이터시스템/team/data/goodchoice_Haeundae[' + nowDatetime +'].csv', 'r', encoding='utf8') #노트북
# f = open('D:/webcc/data/goodchoice_Haeundae[' + nowDatetime +'].csv', 'r', encoding='utf8') #622 컴퓨터

# 부산 부산역
# f = open('./data/info_busan_station[' + nowDatetime +'].csv', 'r', encoding='utf8') #노트북
# f = open('D:/webcc/data/goodchoice_station[' + nowDatetime +'].csv', 'r', encoding='utf8') #622 컴퓨터

# 부산 서면
f = open('./data/info_busan_seomyun[' + nowDatetime +'].csv', 'r', encoding='utf8') #노트북
# f = open('D:/webcc/data/goodchoice_station[' + nowDatetime +'].csv', 'r', encoding='utf8') #622 컴퓨터
rdr = csv.reader(f)

# %%
for line in rdr:
    addr = line[0]
    rs = requests.get(addr)

    rs.encoding = None
    html = rs.text
    soup = BeautifulSoup(html, 'html.parser')

    try:
        tarname = soup.select('#content > div.top > div.right')
        rname = soup.find("div", {"class" : "info"})
        name = rname.find("h2")
        name = name.text

        tarbasic_info = soup.select('#content > article.detail_info > section.default_info')
        basic_info = ''
        for text in tarbasic_info:
            basic_info += text.getText()
        
        basic_info = extracts.sub('', basic_info)
        basic_info = re.sub(' +', ' ', basic_info)
        basic_info = '"'+basic_info+'"'

        tarcost_info = soup.select('#content > article.detail_info.on > section.table_wrap > div:nth-child(2) > table:nth-child(2)')
        rcost_info = soup.find("table", {"class" : "table_type_02"})
        cost_info = rcost_info.find("span")
        cost_info = cost_info.text

        tarstar_info = soup.select('#content > div.top > div.right > div.info')
        rstar_info = soup.find("div", {"class" : "score_cnt"})
        avg_star_info = rstar_info.find("span").text[0:4]

        data.write(name)
        data.write('|')
        data.write(basic_info)
        data.write('|')
        data.write(cost_info)
        data.write('|')
        data.write(avg_star_info)
        data.write('\n')

    except:
        continue

f.close()
data.close()
driver.close()

# %%
data_r.write('name')
data_r.write("|")
data_r.write('review')
data_r.write("|")
data_r.write('star')
data_r.write('\n')

# %%
# 서울
# d = open('D:/webcc/data/goodchoice_seoul_Gangnam[' + nowDatetime +'].csv', 'r', encoding='utf8') # 622 컴퓨터
# d = open('C:/python/빅데이터시스템/team/data/goodchoice_seoul_Gangnam[' + nowDatetime +'].csv', 'r', encoding='utf8') # 노트북

# 서울 용산, 중구, 명동, 이태원
# d = open('D:/webcc/data/goodchoice_seoul_Itaewon[' + nowDatetime +'].csv', 'r', encoding='utf8') # 622 컴퓨터
# d = open('C:/python/빅데이터시스템/team/data/goodchoice_seoul_Itaewon[' + nowDatetime +'].csv', 'r', encoding='utf8') # 노트북

# 서울 건대, 광진, 구의
# d = open('D:/webcc/data/goodchoice_seoul_Itaewon[' + nowDatetime +'].csv', 'r', encoding='utf8') # 622 컴퓨터
# d = open('C:/python/빅데이터시스템/team/data/goodchoice_seoul_Itaewon[' + nowDatetime +'].csv', 'r', encoding='utf8') # 노트북

# 부산 광안리
# d = open('C:/python/빅데이터시스템/team/data/goodchoice_busan_Gwangalli[' + nowDatetime +'].csv', 'r', encoding='utf8') # 노트북
# d = open('D:/webcc/data/goodchoice_busan_Gwangalli[' + nowDatetime +'].csv', 'r', encoding='utf8') # 622 컴퓨터

# 부산 해운대
# d = open('C:/python/빅데이터시스템/team/data/goodchoice_busan_Haeundae[' + nowDatetime +'].csv', 'r', encoding='utf8') # 노트북
# d = open('D:/webcc/data/goodchoice_busan_Haeundae[' + nowDatetime +'].csv', 'r', encoding='utf8') # 622 컴퓨터

# 부산 부산역
# d = open('C:/python/빅데이터시스템/team/data/goodchoice_busan_station[' + nowDatetime +'].csv', 'r', encoding='utf8') # 노트북
# d = open('D:/webcc/data/goodchoice_busan_Haeundae[' + nowDatetime +'].csv', 'r', encoding='utf8') # 622 컴퓨터

# 부산 서면
d = open('C:/python/빅데이터시스템/team/data/goodchoice_busan_seomyun[' + nowDatetime +'].csv', 'r', encoding='utf8') # 노트북
# d = open('D:/webcc/data/goodchoice_busan_Haeundae[' + nowDatetime +'].csv', 'r', encoding='utf8') # 622 컴퓨터
rdd = csv.reader(d)

# %%
driver = webdriver.Chrome("chromedriver.exe")

for line in rdd:
    for i in range(1, 11):
        add = line[0]
        addx = f'{add}'+'#{}'.format(i)
        driver.get(addx)
        driver.get(addx)

        soups = BeautifulSoup(driver.page_source, 'html.parser')
        tarname = soups.select('#content > div.top > div.right')
        rname = soups.find("div", {"class" : "info"})
        name = rname.find("h2")
        name = name.text
      
        # 서울 강남
        # data_r = open('D:/webcc/reviews/reviews_seoul_Gangnam[' + nowDatetime +'].csv', 'a', encoding='utf8') # 622
        # data_r = open('C:/python/빅데이터시스템/team/reviews/reviews_seoul_Gangnam[' + nowDatetime + '].csv', 'a', encoding='utf8') #노트북

        # 서울 용산, 중구, 명동, 이태원
        # data_r = open('D:/webcc/reviews/reviews_seoul_Itaewon[' + nowDatetime +'].csv', 'a', encoding='utf8') # 622
        #data_r = open('C:/python/빅데이터시스템/team/reviews/reviews_seoul_Itaewon[' + nowDatetime + '].csv', 'a', encoding='utf8') #노트북

        # 서울 건대, 광진, 구의
        # data_r = open('D:/webcc/reviews/reviews_seoul_Itaewon[' + nowDatetime +'].csv', 'a', encoding='utf8') # 622
        # data_r = open('C:/python/빅데이터시스템/team/reviews/reviews_seoul_Gundae[' + nowDatetime + '].csv', 'a', encoding='utf8') #노트북
      
        # 부산 광안리
        # data_r = open('D:/webcc/reviews/reviews_busan_Gwangalli[' + nowDatetime +'].csv', 'a', encoding='utf8') #622
        # data_r = open('C:/python/빅데이터시스템/team/reviews/reviews_Gwangalli[' + nowDatetime +'].csv', 'a', encoding='utf8') # 노트북

        # 부산 해운대
        # data_r = open('D:/webcc/reviews/reviews_busan_Haeundae[' + nowDatetime +'].csv', 'a', encoding='utf8') #622
        # data_r = open('C:/python/빅데이터시스템/team/reviews/reviews_busan_Haeundae[' + nowDatetime +'].csv', 'a', encoding='utf8') # 노트북

        # 부산 부산역
        # data_r = open('D:/webcc/reviews/reviews_busan_Haeundae[' + nowDatetime +'].csv', 'a', encoding='utf8') #622
        # data_r = open('C:/python/빅데이터시스템/team/reviews/reviews_busan_station[' + nowDatetime +'].csv', 'a', encoding='utf8') # 노트북

        # 부산 서면
        # data_r = open('D:/webcc/reviews/reviews_busan_Haeundae[' + nowDatetime +'].csv', 'a', encoding='utf8') #622
        data_r = open('C:/python/빅데이터시스템/team/reviews/reviews_busan_seomyun[' + nowDatetime +'].csv', 'a', encoding='utf8') # 노트북
        
        soups = BeautifulSoup(driver.page_source, 'html.parser')
        reviews = soups.select('#review > ul > li')

        for review in reviews:
            treview = review.select_one('.txt')
            tstar = review.select_one('.score_wrap_sm .num')
            review_text = str(treview)
            star_text = str(tstar)

            data_r.write(name)
            data_r.write("|")
            data_r.write(review_text)
            data_r.write("|")
            data_r.write(star_text)
            data_r.write('\n')
            
    data_r.close()  
 
d.close()
driver.close()
